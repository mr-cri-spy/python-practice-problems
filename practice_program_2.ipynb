# %% [markdown]
# <a href="https://colab.research.google.com/github/mr-cri-spy/python-practice-problems/blob/main/practice_program_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Write a program to print all numbers from 1 to 100 that are divisible by both 3 and 5

# %%
for i in range(1,101):
  if i % 3==0 and i%5 ==0:
    print(i)
# Out:
# 15
# 30
# 45
# 60
# 75
# 90

# %% [markdown]
# Design a program to continuously input a number from user & print if it is positive or negative until the user enters “Quit”

# %%
while True:
  user_input = input("Enter a number or 'q' to quit to stop")

  if user_input.lower() == "quit":
    print("Program ended ")
    break

  number = float(user_input)
  if number > 0:
    print("positive num")

  elif number < 0:
    print("negative num")

  else:
    print("Zero")
# Out:
# Enter a number or 'q' to quit to stop2
# positive num
# Enter a number or 'q' to quit to stop-2
# negative num
# Enter a number or 'q' to quit to stop0
# Zero
# Enter a number or 'q' to quit to stopquit
# Program ended

# %% [markdown]
# Design a simple calculator program in Python.
#
# Create a function named calculator(a, b, operation) that performs an arithmetic operation based on the given parameter.
#
# The function should take:
#
# a → first number
#
# b → second number
#
# operation → arithmetic operation to perform
#
# The operation parameter can have the following values:
#
# '+' → Addition
#
# '-' → Subtraction
#
# '*' → Multiplication
#
# '/' → Division
#
# The function should return the result of the operation.

# %%
a = int(input("Enter the first number:"))
b = int(input("Enter the second number:"))
operation = input("enter the operation :")

if operation == "+":
  print(a+b)

elif operation == "-":
  print(a-b)

elif operation == "*":
  print(a*b)

elif operation == "/":
  print(a/b)

else:
  print("invalid operation")
# Out:
# Enter the first number:1
# Enter the second number:10
# enter the operation :+
# 11
